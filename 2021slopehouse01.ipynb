# %%
import numpy as np 
import matplotlib.pyplot as plt 
import matplotlib.colors as mcolors
import pandas as pd

# %%
slopehouse32_df=pd.read_csv('./32處山坡地老舊聚落分布現況-1.csv',encoding='cp950')

# %%
slopehouse32_df
# Out:
#     聚落編號  行政區                                聚落位置    備註   建物門牌     戶數    設籍人數  \
# 0      1   信義                      松山路底福德街51巷山坡聚落   已拆遷   38.0   65.0   170.0
# 1      2   信義                    松山路650巷15弄南側山坡聚落   已拆遷   62.0   81.0   209.0
# 2      3   信義                   和平東路三段435巷29弄山坡聚落   NaN    1.0    0.0     0.0
# 3      4   信義                         虎林街272巷山坡聚落   NaN   10.0   12.0    29.0
# 4      5   信義               臥龍街427巷及395巷23弄附近山坡聚落   NaN    3.0    5.0    16.0
# 5      6   信義               臥龍街427巷及395巷23弄附近山坡聚落   NaN    3.0    3.0     6.0
# 6      7   信義           臥龍街427巷5弄南側至427巷6,7弄間山坡聚落   NaN   67.0   72.0   194.0
# 7      8   信義                     吳興街底靠山腳及坑溝之山坡聚落   NaN    5.0    7.0    24.0
# 8   08-1   信義                     吳興街583巷117弄山坡聚落   已拆遷   33.0   38.0   114.0
# 9      9   信義               聯勤技術訓練中心左側兩系谷溝沿線舊山坡聚落   NaN   10.0   20.0    69.0
# 10    10   北投                   貴子坑溪水磨坑溪匯流口上游山坡聚落   NaN   35.0   44.0   151.0
# 11    11   北投                     幽雅路杏林巷曹洞寺附近山坡聚落   NaN    9.0   19.0    51.0
# 12    12   士林                          中社路1段9巷翠山莊  解除列管    NaN    NaN     NaN
# 13    13   士林                     臨溪路74巷及100巷山坡聚落   NaN   20.0   26.0    74.0
# 14    14   士林                         仰德大道復興橋山坡聚落  解除列管    NaN    NaN     NaN
# 15    15   士林                    中山北路5段復興電台後方山坡聚落   NaN   15.0   21.0    71.0
# 16    16   大安             臥龍街426巷及臥龍街380至418號山坡聚落   NaN   21.0   17.0    55.0
# 17    17   大安                    臥龍街436巷捷運線東側山坡聚落   NaN   52.0   57.0   145.0
# 18    18   大安                    臥龍街436巷捷運線西側山坡聚落   NaN    5.0    4.0    14.0
# 19    19   中山  北安路501巷、689巷及自強隧道南洞口東側雞南山沿山腳一帶山坡聚落   已拆遷   39.0   69.0   180.0
# 20    20   中山                    通北街118巷及146巷山坡聚落   NaN   13.0   18.0    39.0
# 21    21   內湖   內湖路一段47巷西側及內湖路一段39巷東側(靠劍南路下方)山坡聚落   NaN   10.0   16.0    29.0
# 22    22   文山                   景興路仙跡岩下方紫範宮一帶山坡聚落   NaN   20.0   19.0    56.0
# 23    23   南港                  中南街134巷及168巷一帶山坡聚落   NaN   37.0   47.0   140.0
# 24    24   南港       舊莊街2段156號後側﹑160號附近及306巷1號山坡聚落   NaN   17.0   29.0   109.0
# 25    25   大安                       臥龍街379巷對面山坡聚落   NaN   12.0   17.0    37.0
# 26    26   文山                        木柵路5段象頭埔山坡聚落   NaN    4.0   16.0    59.0
# 27    27   信義          信義路5段150巷342弄東側(慈惠堂)附近山坡聚落   NaN   12.0   14.0    42.0
# 28    28   信義                    吳興街600巷55弄對面山坡聚落  解除列管    NaN    NaN     NaN
# 29    29   南港                     研究院路4段下寮橋北側山坡聚落  解除列管    NaN    NaN     NaN
# 30    30   南港                       成福路底北興宮附近山坡聚落   NaN   19.0   33.0    84.0
# 31    31   大安                 基隆路3段155巷176弄東側山坡聚落   NaN   48.0   57.0   130.0
# 32   NaN  NaN                                 NaN   NaN  620.0  826.0  2297.0
#
#         拆除時間  Unnamed: 8
# 0    90/4/08         NaN
# 1    93/7/30         NaN
# 2        NaN         NaN
# 3        NaN         NaN
# 4        NaN         NaN
# 5        NaN         NaN
# 6        NaN         NaN
# 7        NaN         NaN
# 8   90/01/07         NaN
# 9        NaN         NaN
# 10       NaN         NaN
# 11       NaN         NaN
# 12       NaN         NaN
# 13       NaN         NaN
# 14       NaN         NaN
# 15       NaN         NaN
# 16       NaN         NaN
# 17       NaN         NaN
# 18       NaN         NaN
# 19  90/12/15         NaN
# 20       NaN         NaN
# 21       NaN         NaN
# 22       NaN         NaN
# 23       NaN         NaN
# 24       NaN         NaN
# 25       NaN         NaN
# 26       NaN         NaN
# 27       NaN         NaN
# 28       NaN         NaN
# 29       NaN         NaN
# 30       NaN         NaN
# 31       NaN         NaN
# 32       NaN         NaN

# %%
df = slopehouse32_df.drop([slopehouse32_df.columns[8]], axis=1)
df
# Out:
#     聚落編號  行政區                                聚落位置    備註   建物門牌     戶數    設籍人數  \
# 0      1   信義                      松山路底福德街51巷山坡聚落   已拆遷   38.0   65.0   170.0
# 1      2   信義                    松山路650巷15弄南側山坡聚落   已拆遷   62.0   81.0   209.0
# 2      3   信義                   和平東路三段435巷29弄山坡聚落   NaN    1.0    0.0     0.0
# 3      4   信義                         虎林街272巷山坡聚落   NaN   10.0   12.0    29.0
# 4      5   信義               臥龍街427巷及395巷23弄附近山坡聚落   NaN    3.0    5.0    16.0
# 5      6   信義               臥龍街427巷及395巷23弄附近山坡聚落   NaN    3.0    3.0     6.0
# 6      7   信義           臥龍街427巷5弄南側至427巷6,7弄間山坡聚落   NaN   67.0   72.0   194.0
# 7      8   信義                     吳興街底靠山腳及坑溝之山坡聚落   NaN    5.0    7.0    24.0
# 8   08-1   信義                     吳興街583巷117弄山坡聚落   已拆遷   33.0   38.0   114.0
# 9      9   信義               聯勤技術訓練中心左側兩系谷溝沿線舊山坡聚落   NaN   10.0   20.0    69.0
# 10    10   北投                   貴子坑溪水磨坑溪匯流口上游山坡聚落   NaN   35.0   44.0   151.0
# 11    11   北投                     幽雅路杏林巷曹洞寺附近山坡聚落   NaN    9.0   19.0    51.0
# 12    12   士林                          中社路1段9巷翠山莊  解除列管    NaN    NaN     NaN
# 13    13   士林                     臨溪路74巷及100巷山坡聚落   NaN   20.0   26.0    74.0
# 14    14   士林                         仰德大道復興橋山坡聚落  解除列管    NaN    NaN     NaN
# 15    15   士林                    中山北路5段復興電台後方山坡聚落   NaN   15.0   21.0    71.0
# 16    16   大安             臥龍街426巷及臥龍街380至418號山坡聚落   NaN   21.0   17.0    55.0
# 17    17   大安                    臥龍街436巷捷運線東側山坡聚落   NaN   52.0   57.0   145.0
# 18    18   大安                    臥龍街436巷捷運線西側山坡聚落   NaN    5.0    4.0    14.0
# 19    19   中山  北安路501巷、689巷及自強隧道南洞口東側雞南山沿山腳一帶山坡聚落   已拆遷   39.0   69.0   180.0
# 20    20   中山                    通北街118巷及146巷山坡聚落   NaN   13.0   18.0    39.0
# 21    21   內湖   內湖路一段47巷西側及內湖路一段39巷東側(靠劍南路下方)山坡聚落   NaN   10.0   16.0    29.0
# 22    22   文山                   景興路仙跡岩下方紫範宮一帶山坡聚落   NaN   20.0   19.0    56.0
# 23    23   南港                  中南街134巷及168巷一帶山坡聚落   NaN   37.0   47.0   140.0
# 24    24   南港       舊莊街2段156號後側﹑160號附近及306巷1號山坡聚落   NaN   17.0   29.0   109.0
# 25    25   大安                       臥龍街379巷對面山坡聚落   NaN   12.0   17.0    37.0
# 26    26   文山                        木柵路5段象頭埔山坡聚落   NaN    4.0   16.0    59.0
# 27    27   信義          信義路5段150巷342弄東側(慈惠堂)附近山坡聚落   NaN   12.0   14.0    42.0
# 28    28   信義                    吳興街600巷55弄對面山坡聚落  解除列管    NaN    NaN     NaN
# 29    29   南港                     研究院路4段下寮橋北側山坡聚落  解除列管    NaN    NaN     NaN
# 30    30   南港                       成福路底北興宮附近山坡聚落   NaN   19.0   33.0    84.0
# 31    31   大安                 基隆路3段155巷176弄東側山坡聚落   NaN   48.0   57.0   130.0
# 32   NaN  NaN                                 NaN   NaN  620.0  826.0  2297.0
#
#         拆除時間
# 0    90/4/08
# 1    93/7/30
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8   90/01/07
# 9        NaN
# 10       NaN
# 11       NaN
# 12       NaN
# 13       NaN
# 14       NaN
# 15       NaN
# 16       NaN
# 17       NaN
# 18       NaN
# 19  90/12/15
# 20       NaN
# 21       NaN
# 22       NaN
# 23       NaN
# 24       NaN
# 25       NaN
# 26       NaN
# 27       NaN
# 28       NaN
# 29       NaN
# 30       NaN
# 31       NaN
# 32       NaN

# %%
df.columns
# Out:
# Index(['聚落編號', '行政區', '聚落位置', '備註', '建物門牌', '戶數', '設籍人數', '拆除時間'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=33, step=1)

# %%
path = model.cost_complexity_pruning_path(X_train, Y_train)
ccp_alphas, impurities = path.ccp_alphas, path.impurities

fig, ax = plt.figure(figsize=(16, 8))
ax.plot(ccp_alphas[:-1], impurities[:-1], marker='o', drawstyle='steps-post')
ax.set_xlabel('effective alpha')
ax.set_ylabel('total impurity of leaves')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-35045390d8b2> in <module>
# ----> 1 path = model.cost_complexity_pruning_path(X_train, Y_train)
#       2 ccp_alphas, impurities = path.ccp_alphas, path.impurities
#       3
#       4 fig, ax = plt.figure(figsize=(16, 8))
#       5 ax.plot(ccp_alphas[:-1], impurities[:-1], marker='o', drawstyle='steps-post')
#
# NameError: name 'model' is not defined
